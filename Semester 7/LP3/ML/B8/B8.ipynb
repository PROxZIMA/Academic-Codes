# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import cross_val_score
from sklearn.ensemble import RandomForestClassifier

# %% [markdown]
# ## **Loading the Dataset**
# First we load the dataset and find out the number of columns, rows, NULL values, etc.

# %%
train = pd.read_csv('train.csv')
test = pd.read_csv('test.csv')

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Pclass       418 non-null    int64
#  2   Name         418 non-null    object
#  3   Sex          418 non-null    object
#  4   Age          332 non-null    float64
#  5   SibSp        418 non-null    int64
#  6   Parch        418 non-null    int64
#  7   Ticket       418 non-null    object
#  8   Fare         417 non-null    float64
#  9   Cabin        91 non-null     object
#  10  Embarked     418 non-null    object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 36.0+ KB

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
test.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %% [markdown]
# ## **Cleaning**

# %%
train.corr().style.background_gradient(cmap='BuGn')
# Out:
# <style type="text/css">
# #T_67b58_row0_col0, #T_67b58_row1_col1, #T_67b58_row2_col2, #T_67b58_row3_col3, #T_67b58_row4_col4, #T_67b58_row5_col5, #T_67b58_row6_col6 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_67b58_row0_col1 {
#   background-color: #cdece6;
#   color: #000000;
# }
# #T_67b58_row0_col2 {
#   background-color: #acdfd4;
#   color: #000000;
# }
# #T_67b58_row0_col3 {
#   background-color: #bae5dc;
#   color: #000000;
# }
# #T_67b58_row0_col4, #T_67b58_row3_col1 {
#   background-color: #d8f0ef;
#   color: #000000;
# }
# #T_67b58_row0_col5 {
#   background-color: #dff3f4;
#   color: #000000;
# }
# #T_67b58_row0_col6 {
#   background-color: #9fdacc;
#   color: #000000;
# }
# #T_67b58_row1_col0, #T_67b58_row5_col0 {
#   background-color: #f0f9fb;
#   color: #000000;
# }
# #T_67b58_row1_col2 {
#   background-color: #e3f4f8;
#   color: #000000;
# }
# #T_67b58_row1_col3, #T_67b58_row1_col4 {
#   background-color: #d4efec;
#   color: #000000;
# }
# #T_67b58_row1_col5 {
#   background-color: #d1eee9;
#   color: #000000;
# }
# #T_67b58_row1_col6 {
#   background-color: #60bf9c;
#   color: #000000;
# }
# #T_67b58_row2_col0 {
#   background-color: #f4fbfc;
#   color: #000000;
# }
# #T_67b58_row2_col1, #T_67b58_row2_col3, #T_67b58_row2_col6, #T_67b58_row3_col4, #T_67b58_row3_col5, #T_67b58_row4_col0, #T_67b58_row6_col2 {
#   background-color: #f7fcfd;
#   color: #000000;
# }
# #T_67b58_row2_col4 {
#   background-color: #b8e4db;
#   color: #000000;
# }
# #T_67b58_row2_col5 {
#   background-color: #dbf2f2;
#   color: #000000;
# }
# #T_67b58_row3_col0 {
#   background-color: #ebf7fa;
#   color: #000000;
# }
# #T_67b58_row3_col2 {
#   background-color: #e7f6f9;
#   color: #000000;
# }
# #T_67b58_row3_col6 {
#   background-color: #88d1bd;
#   color: #000000;
# }
# #T_67b58_row4_col1 {
#   background-color: #d1eeea;
#   color: #000000;
# }
# #T_67b58_row4_col2 {
#   background-color: #8cd2bf;
#   color: #000000;
# }
# #T_67b58_row4_col3 {
#   background-color: #f1fafc;
#   color: #000000;
# }
# #T_67b58_row4_col5 {
#   background-color: #63c0a0;
#   color: #000000;
# }
# #T_67b58_row4_col6 {
#   background-color: #77c9b0;
#   color: #000000;
# }
# #T_67b58_row5_col1 {
#   background-color: #b2e2d7;
#   color: #000000;
# }
# #T_67b58_row5_col2 {
#   background-color: #9ddacb;
#   color: #000000;
# }
# #T_67b58_row5_col3 {
#   background-color: #e4f5f8;
#   color: #000000;
# }
# #T_67b58_row5_col4 {
#   background-color: #56ba91;
#   color: #f1f1f1;
# }
# #T_67b58_row5_col6 {
#   background-color: #68c3a6;
#   color: #000000;
# }
# #T_67b58_row6_col0 {
#   background-color: #eef8fb;
#   color: #000000;
# }
# #T_67b58_row6_col1 {
#   background-color: #7dccb5;
#   color: #000000;
# }
# #T_67b58_row6_col3 {
#   background-color: #a8ded2;
#   color: #000000;
# }
# #T_67b58_row6_col4 {
#   background-color: #a0dbcd;
#   color: #000000;
# }
# #T_67b58_row6_col5 {
#   background-color: #a7ddd1;
#   color: #000000;
# }
# </style>
# <table id="T_67b58">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_67b58_level0_col0" class="col_heading level0 col0" >PassengerId</th>
#       <th id="T_67b58_level0_col1" class="col_heading level0 col1" >Survived</th>
#       <th id="T_67b58_level0_col2" class="col_heading level0 col2" >Pclass</th>
#       <th id="T_67b58_level0_col3" class="col_heading level0 col3" >Age</th>
#       <th id="T_67b58_level0_col4" class="col_heading level0 col4" >SibSp</th>
#       <th id="T_67b58_level0_col5" class="col_heading level0 col5" >Parch</th>
#       <th id="T_67b58_level0_col6" class="col_heading level0 col6" >Fare</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_67b58_level0_row0" class="row_heading level0 row0" >PassengerId</th>
#       <td id="T_67b58_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_67b58_row0_col1" class="data row0 col1" >-0.005007</td>
#       <td id="T_67b58_row0_col2" class="data row0 col2" >-0.035144</td>
#       <td id="T_67b58_row0_col3" class="data row0 col3" >0.036847</td>
#       <td id="T_67b58_row0_col4" class="data row0 col4" >-0.057527</td>
#       <td id="T_67b58_row0_col5" class="data row0 col5" >-0.001652</td>
#       <td id="T_67b58_row0_col6" class="data row0 col6" >0.012658</td>
#     </tr>
#     <tr>
#       <th id="T_67b58_level0_row1" class="row_heading level0 row1" >Survived</th>
#       <td id="T_67b58_row1_col0" class="data row1 col0" >-0.005007</td>
#       <td id="T_67b58_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_67b58_row1_col2" class="data row1 col2" >-0.338481</td>
#       <td id="T_67b58_row1_col3" class="data row1 col3" >-0.077221</td>
#       <td id="T_67b58_row1_col4" class="data row1 col4" >-0.035322</td>
#       <td id="T_67b58_row1_col5" class="data row1 col5" >0.081629</td>
#       <td id="T_67b58_row1_col6" class="data row1 col6" >0.257307</td>
#     </tr>
#     <tr>
#       <th id="T_67b58_level0_row2" class="row_heading level0 row2" >Pclass</th>
#       <td id="T_67b58_row2_col0" class="data row2 col0" >-0.035144</td>
#       <td id="T_67b58_row2_col1" class="data row2 col1" >-0.338481</td>
#       <td id="T_67b58_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_67b58_row2_col3" class="data row2 col3" >-0.369226</td>
#       <td id="T_67b58_row2_col4" class="data row2 col4" >0.083081</td>
#       <td id="T_67b58_row2_col5" class="data row2 col5" >0.018443</td>
#       <td id="T_67b58_row2_col6" class="data row2 col6" >-0.549500</td>
#     </tr>
#     <tr>
#       <th id="T_67b58_level0_row3" class="row_heading level0 row3" >Age</th>
#       <td id="T_67b58_row3_col0" class="data row3 col0" >0.036847</td>
#       <td id="T_67b58_row3_col1" class="data row3 col1" >-0.077221</td>
#       <td id="T_67b58_row3_col2" class="data row3 col2" >-0.369226</td>
#       <td id="T_67b58_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_67b58_row3_col4" class="data row3 col4" >-0.308247</td>
#       <td id="T_67b58_row3_col5" class="data row3 col5" >-0.189119</td>
#       <td id="T_67b58_row3_col6" class="data row3 col6" >0.096067</td>
#     </tr>
#     <tr>
#       <th id="T_67b58_level0_row4" class="row_heading level0 row4" >SibSp</th>
#       <td id="T_67b58_row4_col0" class="data row4 col0" >-0.057527</td>
#       <td id="T_67b58_row4_col1" class="data row4 col1" >-0.035322</td>
#       <td id="T_67b58_row4_col2" class="data row4 col2" >0.083081</td>
#       <td id="T_67b58_row4_col3" class="data row4 col3" >-0.308247</td>
#       <td id="T_67b58_row4_col4" class="data row4 col4" >1.000000</td>
#       <td id="T_67b58_row4_col5" class="data row4 col5" >0.414838</td>
#       <td id="T_67b58_row4_col6" class="data row4 col6" >0.159651</td>
#     </tr>
#     <tr>
#       <th id="T_67b58_level0_row5" class="row_heading level0 row5" >Parch</th>
#       <td id="T_67b58_row5_col0" class="data row5 col0" >-0.001652</td>
#       <td id="T_67b58_row5_col1" class="data row5 col1" >0.081629</td>
#       <td id="T_67b58_row5_col2" class="data row5 col2" >0.018443</td>
#       <td id="T_67b58_row5_col3" class="data row5 col3" >-0.189119</td>
#       <td id="T_67b58_row5_col4" class="data row5 col4" >0.414838</td>
#       <td id="T_67b58_row5_col5" class="data row5 col5" >1.000000</td>
#       <td id="T_67b58_row5_col6" class="data row5 col6" >0.216225</td>
#     </tr>
#     <tr>
#       <th id="T_67b58_level0_row6" class="row_heading level0 row6" >Fare</th>
#       <td id="T_67b58_row6_col0" class="data row6 col0" >0.012658</td>
#       <td id="T_67b58_row6_col1" class="data row6 col1" >0.257307</td>
#       <td id="T_67b58_row6_col2" class="data row6 col2" >-0.549500</td>
#       <td id="T_67b58_row6_col3" class="data row6 col3" >0.096067</td>
#       <td id="T_67b58_row6_col4" class="data row6 col4" >0.159651</td>
#       <td id="T_67b58_row6_col5" class="data row6 col5" >0.216225</td>
#       <td id="T_67b58_row6_col6" class="data row6 col6" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
train.drop(['PassengerId', 'Name', 'Ticket', 'Cabin'], axis=1, inplace=True)
test.drop(['PassengerId', 'Name', 'Ticket', 'Cabin'], axis=1, inplace=True)

# %%
train.isna().sum()
# Out:
# Survived      0
# Pclass        0
# Sex           0
# Age         177
# SibSp         0
# Parch         0
# Fare          0
# Embarked      2
# dtype: int64

# %%
test.isna().sum()
# Out:
# Pclass       0
# Sex          0
# Age         86
# SibSp        0
# Parch        0
# Fare         1
# Embarked     0
# dtype: int64

# %%
train['Embarked'] = train.Embarked.fillna(train.Embarked.dropna().max())
test['Fare'] = test.Fare.fillna(test.Fare.dropna().mean())

# %%
# we will guess the age from Pclass and Sex:

guess_ages = np.zeros((2,3))
guess_ages
# Out:
# array([[0., 0., 0.],
#        [0., 0., 0.]])

# %% [markdown]
# **Now we iterate over Sex (0 or 1) and Pclass (1, 2, 3) to calculate guessed values of Age for the six combinations.**

# %%
combine = [train , test]

# Converting Sex categories (male and female) to 0 and 1:
for dataset in combine:
    dataset['Sex'] = dataset['Sex'].map( {'female': 1, 'male': 0} ).astype(int)

# Filling missed age feature:
for dataset in combine:
    for i in range(0, 2):
        for j in range(0, 3):
            guess_df = dataset[(dataset['Sex'] == i) & \
                                  (dataset['Pclass'] == j+1)]['Age'].dropna()
            age_guess = guess_df.median()

            # Convert random age float to nearest .5 age
            guess_ages[i,j] = int( age_guess/0.5 + 0.5 ) * 0.5
            
    for i in range(0, 2):
        for j in range(0, 3):
            dataset.loc[ (dataset.Age.isnull()) & (dataset.Sex == i) & (dataset.Pclass == j+1),\
                    'Age'] = guess_ages[i,j]

    dataset['Age'] = dataset['Age'].astype(int)

train.head()
# Out:
#    Survived  Pclass  Sex  Age  SibSp  Parch     Fare Embarked
# 0         0       3    0   22      1      0   7.2500        S
# 1         1       1    1   38      1      0  71.2833        C
# 2         1       3    1   26      0      0   7.9250        S
# 3         1       1    1   35      1      0  53.1000        S
# 4         0       3    0   35      0      0   8.0500        S

# %%
train.describe()
# Out:
#          Survived      Pclass         Sex         Age       SibSp       Parch  \
# count  891.000000  891.000000  891.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642    0.352413   29.072952    0.523008    0.381594
# std      0.486592    0.836071    0.477990   13.326339    1.102743    0.806057
# min      0.000000    1.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000    0.000000   21.000000    0.000000    0.000000
# 50%      0.000000    3.000000    0.000000   26.000000    0.000000    0.000000
# 75%      1.000000    3.000000    1.000000   36.000000    1.000000    0.000000
# max      1.000000    3.000000    1.000000   80.000000    8.000000    6.000000
#
#              Fare
# count  891.000000
# mean    32.204208
# std     49.693429
# min      0.000000
# 25%      7.910400
# 50%     14.454200
# 75%     31.000000
# max    512.329200

# %% [markdown]
# # **Splitting the Dataset**
# Training and Test Set

# %%
X_train = pd.get_dummies(train.drop(['Survived'], axis=1))
X_test  = pd.get_dummies(test)
y_train = train['Survived']

# %% [markdown]
# # **Machine Learning model**

# %%
def print_scores(model, X_train, Y_train, predictions, cv_splites=10):
    print("The mean accuracy score of the train data is %.5f" % model.score(X_train, Y_train))
    CV_scores = cross_val_score(model, X_train, Y_train, cv=cv_splites)
    print("The individual cross-validation scores are: \n",CV_scores)
    print("The minimum cross-validation score is %.3f" % min(CV_scores))
    print("The maximum cross-validation score is %.3f" % max(CV_scores))
    print("The mean  cross-validation   score is %.5f ± %0.2f" % (CV_scores.mean(), CV_scores.std() * 2))

# %%
model = RandomForestClassifier(n_estimators= 80 ,max_depth=5 , max_features=8 ,min_samples_split=3 ,random_state=7)
model.fit(X_train, y_train)
predictions = model.predict(X_test)
print_scores(model, X_train, y_train, predictions)
# Out:
# The mean accuracy score of the train data is 0.85859
# The individual cross-validation scores are:
#  [0.76666667 0.85393258 0.75280899 0.91011236 0.88764045 0.80898876
#  0.80898876 0.78651685 0.87640449 0.84269663]
# The minimum cross-validation score is 0.753
# The maximum cross-validation score is 0.910
# The mean  cross-validation   score is 0.82948 ± 0.10
